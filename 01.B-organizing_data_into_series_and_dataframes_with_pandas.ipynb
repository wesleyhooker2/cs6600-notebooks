# %% [markdown]
# # 01.B: Organizing data into  Series and DataFrames with Pandas
# Pandas comes with two main data structures: Series and DataFrame. A Series is like a dictionary with keys (also called indexes) and values. A DataFrame represents tabular data with one or more columns.
#
# To use pandas, we first need to import it. Let's also import numpy.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# We can now create series and dataframes
# ## Series
#
# ### Creating a Series
# We can create a Serices by providing an array of values.

# %%
s1 = pd.Series([10,20,30,40,50])
print(s1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# Since we did not provide indexes for our data, numeric zero-based indexes (much like those for arrays) will be automatically provided.
#
# We can also create a Series by providing custom indexes.

# %%
s2 = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])
print(s2)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# Notice that indexes are not required to be unique. For example, we can create a Series with duplicate indexes

# %%
s3 = pd.Series([1,2,3,4,5], index=['a','b','b','c','c']) 
print(s3)
# Out:
# a    1
# b    2
# b    3
# c    4
# c    5
# dtype: int64

# %% [markdown]
# We can create a Series from NumPy arrays.

# %%
snp = pd.Series(np.arange(2, 11, 2), index=['A','B','C','D','F']) 
print(snp)
# Out:
# A     2
# B     4
# C     6
# D     8
# F    10
# dtype: int64

# %% [markdown]
# And indexes could be ranges

# %%
s4 = pd.Series(np.arange(2, 11, 2), index=np.arange(1, 6)) 
print(s4)
# Out:
# 1     2
# 2     4
# 3     6
# 4     8
# 5    10
# dtype: int64

# %% [markdown]
# ### Accessing elements in a Series
# We can use the indexes to extract and/or slice elements within a Series. For example, given the Series `s1`:

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# Here is its element at index 0:

# %%
s1[0]
# Out:
# 10

# %% [markdown]
# and its elements at index 2, 3:

# %%
s1[[2,3]]
# Out:
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# or at the index range from 2 upto but not equal to 4

# %%
s1[2:4]
# Out:
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# And given the Series `s2`:

# %%
s2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# Here is the element at index 'c' followed by the elements from index 'b' to index 'd'

# %%
s2['c']
# Out:
# 3

# %%
s2['b':'d']
# Out:
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# And for a Series with duplicate indexes such as:

# %%
s3
# Out:
# a    1
# b    2
# b    3
# c    4
# c    5
# dtype: int64

# %% [markdown]
# using a duplicate index returns a Series of all the elements with that index.

# %%
s3['b']
# Out:
# b    2
# b    3
# dtype: int64

# %% [markdown]
# The above use of indexes is the same as using `.loc[]` with indexes between `[` and `]`. That is

# %%
print(snp['A':'D'])
print(s3['b'])
# Out:
# A    2
# B    4
# C    6
# D    8
# dtype: int64
# b    2
# b    3
# dtype: int64

# %% [markdown]
# is the same as:

# %%
print(snp.loc['A':'D'])
print(s3.loc['b'])
# Out:
# A    2
# B    4
# C    6
# D    8
# dtype: int64
# b    2
# b    3
# dtype: int64

# %% [markdown]
# But sometimes we want to use the position of the index rather than its actual value to access elements within a Series. We can use `.iloc[]` with zero-based numeric indexe positions between `[` and `]`. The postion 0 means the first index. Given the Series:

# %%
snp
# Out:
# A     2
# B     4
# C     6
# D     8
# F    10
# dtype: int64

# %% [markdown]
# We can access its first element:

# %%
snp.iloc[0]
# Out:
# 2

# %% [markdown]
# And its last element:

# %%
snp.iloc[snp.size - 1]
# Out:
# 10

# %% [markdown]
# With `.iloc` we can index and slice a Series in exactly the same way we can a one-dimensional numpy array. Here is for example how you select every other element in a Series.

# %%
snp.iloc[0::2]
# Out:
# A     2
# C     6
# F    10
# dtype: int64

# %% [markdown]
# And speaking of numpy, we can extract the values of a Series as a numpy array

# %%
snp.values
# Out:
# array([ 2,  4,  6,  8, 10])

# %% [markdown]
# We can also extract its indexes as an array also:

# %%
snp.index
# Out:
# Index(['A', 'B', 'C', 'D', 'F'], dtype='object')

# %% [markdown]
# ## DataFrames
# A data frame is a table with columns and rows. You can think of each column on a DataFrame as a Series sharing the same indexes with all other columns. Each column has a name that can be used to access it.
#
# ### Creating DataFrames
# The easiest way to create a DataFrame is by using a dictionary of arrays. The keys of this dictionary will become column names. Here is a DataFrame with 4 by 9 multiplication table.

# %%
mtable = pd.DataFrame({
    'byOne': [1,2, 3, 4, 5, 6, 7, 8, 9],
    'byTwo': [2, 4, 6, 8, 10, 12, 14, 16, 18],
    'byThree': [3, 6, 9, 12, 15, 18, 21, 24, 27],
    'byFour': [4, 8, 12, 16, 20, 24, 28, 32, 36]
})

mtable
# Out:
#    byOne  byTwo  byThree  byFour
# 0      1      2        3       4
# 1      2      4        6       8
# 2      3      6        9      12
# 3      4      8       12      16
# 4      5     10       15      20
# 5      6     12       18      24
# 6      7     14       21      28
# 7      8     16       24      32
# 8      9     18       27      36

# %% [markdown]
# Since we did not provide indexes, pandas will create zero-based numeric indexed for us, just like it does for a Series.
#
# We can use numpy arrays to create the same table:

# %%
mtable = pd.DataFrame({
    'byOne': np.arange(1, 10),
    'byTwo': 2 * np.arange(1, 10),
    'byThree': 3 * np.arange(1, 10),
    'byFour': 4 * np.arange(1, 10)
})

print(mtable)
# Out:
#    byOne  byTwo  byThree  byFour
# 0      1      2        3       4
# 1      2      4        6       8
# 2      3      6        9      12
# 3      4      8       12      16
# 4      5     10       15      20
# 5      6     12       18      24
# 6      7     14       21      28
# 7      8     16       24      32
# 8      9     18       27      36

# %% [markdown]
# We can create a DataFrame from a two-dimensional array. Given an array:

# %%
table = np.array([
    np.arange(1, 10),
    2 * np.arange(1, 10),
    3 * np.arange(1, 10),
    4 * np.arange(1, 10)
]).T

print(table)
# Out:
# [[ 1  2  3  4]
#  [ 2  4  6  8]
#  [ 3  6  9 12]
#  [ 4  8 12 16]
#  [ 5 10 15 20]
#  [ 6 12 18 24]
#  [ 7 14 21 28]
#  [ 8 16 24 32]
#  [ 9 18 27 36]]

# %% [markdown]
# we can create a DataFrame from it.

# %%
mtable = pd.DataFrame(table)

mtable
# Out:
#    0   1   2   3
# 0  1   2   3   4
# 1  2   4   6   8
# 2  3   6   9  12
# 3  4   8  12  16
# 4  5  10  15  20
# 5  6  12  18  24
# 6  7  14  21  28
# 7  8  16  24  32
# 8  9  18  27  36

# %% [markdown]
# Since we did not provide column names or indexes, Pandas provided numeric zero-based column names and indexes for us. We can provide custom column names to this DataFrame after it was created

# %%
mtable.columns= ['A', 'B', 'C', 'D']
mtable
# Out:
#    A   B   C   D
# 0  1   2   3   4
# 1  2   4   6   8
# 2  3   6   9  12
# 3  4   8  12  16
# 4  5  10  15  20
# 5  6  12  18  24
# 6  7  14  21  28
# 7  8  16  24  32
# 8  9  18  27  36

# %% [markdown]
# We can provide the column names at the time of creating the DataFrame.

# %%
mt = pd.DataFrame(table, columns=['byOne', 'byTwo', 'byThree', 'byFour'])

mt
# Out:
#    byOne  byTwo  byThree  byFour
# 0      1      2        3       4
# 1      2      4        6       8
# 2      3      6        9      12
# 3      4      8       12      16
# 4      5     10       15      20
# 5      6     12       18      24
# 6      7     14       21      28
# 7      8     16       24      32
# 8      9     18       27      36

# %% [markdown]
# We can also provide custom indexes.

# %%
mt = pd.DataFrame(table, 
                  columns=['byOne', 'byTwo', 'byThree', 'byFour'],
                  index=['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9'])

mt
# Out:
#     byOne  byTwo  byThree  byFour
# x1      1      2        3       4
# x2      2      4        6       8
# x3      3      6        9      12
# x4      4      8       12      16
# x5      5     10       15      20
# x6      6     12       18      24
# x7      7     14       21      28
# x8      8     16       24      32
# x9      9     18       27      36

# %% [markdown]
# We can convert the content of a DataFrame to a numpy array:

# %%
mt.values
# Out:
# array([[ 1,  2,  3,  4],
#        [ 2,  4,  6,  8],
#        [ 3,  6,  9, 12],
#        [ 4,  8, 12, 16],
#        [ 5, 10, 15, 20],
#        [ 6, 12, 18, 24],
#        [ 7, 14, 21, 28],
#        [ 8, 16, 24, 32],
#        [ 9, 18, 27, 36]])

# %% [markdown]
# We can get its colum names:

# %%
mt.columns
# Out:
# Index(['byOne', 'byTwo', 'byThree', 'byFour'], dtype='object')

# %% [markdown]
# and its indexes:

# %%
mt.index
# Out:
# Index(['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9'], dtype='object')

# %% [markdown]
# ### Adding new columns and rows to an existing DataFrame
# Given the DataFrame:

# %%
mt
# Out:
#     byOne  byTwo  byThree  byFour
# x1      1      2        3       4
# x2      2      4        6       8
# x3      3      6        9      12
# x4      4      8       12      16
# x5      5     10       15      20
# x6      6     12       18      24
# x7      7     14       21      28
# x8      8     16       24      32
# x9      9     18       27      36

# %% [markdown]
# We can add a new column like this:

# %%
mt['byFive'] = 5 * np.arange(1, 10)

mt
# Out:
#     byOne  byTwo  byThree  byFour  byFive
# x1      1      2        3       4       5
# x2      2      4        6       8      10
# x3      3      6        9      12      15
# x4      4      8       12      16      20
# x5      5     10       15      20      25
# x6      6     12       18      24      30
# x7      7     14       21      28      35
# x8      8     16       24      32      40
# x9      9     18       27      36      45

# %% [markdown]
# And using the `.loc` we can add a new row like this:

# %%
mt.loc['x10'] = 10 * np.arange(1, 6)
mt
# Out:
#      byOne  byTwo  byThree  byFour  byFive
# x1       1      2        3       4       5
# x2       2      4        6       8      10
# x3       3      6        9      12      15
# x4       4      8       12      16      20
# x5       5     10       15      20      25
# x6       6     12       18      24      30
# x7       7     14       21      28      35
# x8       8     16       24      32      40
# x9       9     18       27      36      45
# x10     10     20       30      40      50

# %% [markdown]
# ### Dropping a column or a row from a DataFrame
# We can use the `drop` method to remove a column from a DataFrame. Let's remove the column `byFive` we added above:

# %%
mt.drop(['byFive'], axis=1)
# Out:
#      byOne  byTwo  byThree  byFour
# x1       1      2        3       4
# x2       2      4        6       8
# x3       3      6        9      12
# x4       4      8       12      16
# x5       5     10       15      20
# x6       6     12       18      24
# x7       7     14       21      28
# x8       8     16       24      32
# x9       9     18       27      36
# x10     10     20       30      40

# %% [markdown]
# Here `axis=1` referes to columns. To drop a row we use `axis=0` and provide a index instead of a column name.

# %%
mt.drop(['x10'], axis=0)
# Out:
#     byOne  byTwo  byThree  byFour  byFive
# x1      1      2        3       4       5
# x2      2      4        6       8      10
# x3      3      6        9      12      15
# x4      4      8       12      16      20
# x5      5     10       15      20      25
# x6      6     12       18      24      30
# x7      7     14       21      28      35
# x8      8     16       24      32      40
# x9      9     18       27      36      45

# %% [markdown]
# ### DataFrame indexing and slicing
# We can use the column names and indexes to access individual cells.

# %%
mt['byTwo']['x5']
# Out:
# 10

# %% [markdown]
# To extract a single column, use its name:

# %%
mt['byThree']
# Out:
# x1      3
# x2      6
# x3      9
# x4     12
# x5     15
# x6     18
# x7     21
# x8     24
# x9     27
# x10    30
# Name: byThree, dtype: int64

# %% [markdown]
# And use an array of column names to extract multiple columns

# %%
mt[['byTwo', 'byFour']]
# Out:
#      byTwo  byFour
# x1       2       4
# x2       4       8
# x3       6      12
# x4       8      16
# x5      10      20
# x6      12      24
# x7      14      28
# x8      16      32
# x9      18      36
# x10     20      40

# %% [markdown]
# Use `.loc` to access a specific row using its index:

# %%
mt.loc['x6']
# Out:
# byOne       6
# byTwo      12
# byThree    18
# byFour     24
# byFive     30
# Name: x6, dtype: int64

# %% [markdown]
# Similarly we can extract rows using their index positiosn using `.iloc[]`. We can, for example extract the first row using the its index position `0` (the index itself is `x1`).

# %%
mt.iloc[0]
# Out:
# byOne      1
# byTwo      2
# byThree    3
# byFour     4
# byFive     5
# Name: x1, dtype: int64

# %% [markdown]
# We can also use `.iloc` to access certain columns and rows based on their positions, much like the indexing and slicing of a two-dimensional numpy array. Here is the whole DataFrame:

# %%
mt.iloc[:, :]
# Out:
#      byOne  byTwo  byThree  byFour  byFive
# x1       1      2        3       4       5
# x2       2      4        6       8      10
# x3       3      6        9      12      15
# x4       4      8       12      16      20
# x5       5     10       15      20      25
# x6       6     12       18      24      30
# x7       7     14       21      28      35
# x8       8     16       24      32      40
# x9       9     18       27      36      45
# x10     10     20       30      40      50

# %% [markdown]
# In the `[:, :]`, the first `:` refers to all rows and the second `:` refers to all columns.
#
# Here is the slice from the third(position 2) row to the sixth (position 5) and from second column (position 1) to fifth column(position 4)

# %%
mt.iloc[2:5, 1:4]
# Out:
#     byTwo  byThree  byFour
# x3      6        9      12
# x4      8       12      16
# x5     10       15      20

# %% [markdown]
# And here is every other column and row.

# %%
mt.iloc[::2, ::2]
# Out:
#     byOne  byThree  byFive
# x1      1        3       5
# x3      3        9      15
# x5      5       15      25
# x7      7       21      35
# x9      9       27      45

# %% [markdown]
# Finally we can use the methods `head` and `tail` to display the first couple of records at the top or the bottom of a DataFrame. This is useful for exploring large dataframes.

# %%
print(mt.head())
print(mt.head(6))

print(mt.tail())
print(mt.tail(7))
# Out:
#     byOne  byTwo  byThree  byFour  byFive
# x1      1      2        3       4       5
# x2      2      4        6       8      10
# x3      3      6        9      12      15
# x4      4      8       12      16      20
# x5      5     10       15      20      25
#     byOne  byTwo  byThree  byFour  byFive
# x1      1      2        3       4       5
# x2      2      4        6       8      10
# x3      3      6        9      12      15
# x4      4      8       12      16      20
# x5      5     10       15      20      25
# x6      6     12       18      24      30
#      byOne  byTwo  byThree  byFour  byFive
# x6       6     12       18      24      30
# x7       7     14       21      28      35
# x8       8     16       24      32      40
# x9       9     18       27      36      45
# x10     10     20       30      40      50
#      byOne  byTwo  byThree  byFour  byFive
# x4       4      8       12      16      20
# x5       5     10       15      20      25
# x6       6     12       18      24      30
# x7       7     14       21      28      35
# x8       8     16       24      32      40
# x9       9     18       27      36      45
# x10     10     20       30      40      50

# %% [markdown]
# ### Summarizing dataframes
# Given the following 50 by 10 DataFrame:

# %%
data = pd.DataFrame(np.random.randn(50,10), columns=list('ABCDEFGHIJ'))

# %%
data
# Out:
#            A         B         C         D         E         F         G  \
# 0  -0.259190  0.170754 -1.124605 -0.771915  0.973286 -0.946376  0.305876
# 1  -0.976455 -0.472629  1.482042  1.802155  0.662279  0.645750 -0.178106
# 2  -0.119066  1.017724  0.387901  1.951747 -0.452727 -0.433070 -1.549471
# 3  -0.904966  0.121057 -0.590445  0.960849  0.284733  0.513823 -0.476244
# 4  -0.528633 -0.560854 -0.930889  0.115935 -0.825676 -0.576343 -1.582058
# 5  -0.817783 -0.896830  0.108925 -0.315767  1.115497  0.424926 -0.238312
# 6  -0.147122  1.077447 -0.102460 -0.107177  0.314880  1.698336  0.776135
# 7  -0.669262  0.434427 -0.017197 -0.683233 -0.537647  0.520835  0.303287
# 8  -0.834004  0.883366 -1.273101 -0.254702  1.240292  1.192153  1.461381
# 9  -0.684567  0.802311  0.930923 -0.165524  1.046815 -0.266683 -0.279070
# 45  0.282169  0.343365  1.578689 -0.600533 -0.522298  0.554261 -0.726182
# 46  0.707604 -0.970614  0.042302 -1.823481  1.655602 -2.260195  0.815639
# 47 -0.027832 -0.173137  0.512214  1.564469 -1.328802 -1.156235  0.368367
# 48 -1.360113 -0.838715  2.364942  1.478743 -0.829626 -0.048703  0.532980
# 49 -1.618905 -0.610666  0.103890  0.011803 -1.928664  1.043995 -1.207603
#
#            H         I         J
# 0   0.583443 -0.610982 -1.349279
# 1   0.756834 -0.975938  1.291805
# 2  -0.362654  0.803287  0.037094
# 3   0.506307  1.818822  0.741055
# 4   1.027357  0.241012  0.295293
# 5   0.834312  1.036758  0.570735
# 6  -1.096879  0.101428 -1.019163
# 7  -1.205196 -0.313493  1.381105
# 8  -0.086144 -1.799382  0.380367
# 9  -1.049862  0.510846 -0.874103
# 10  0.081082  0.581584  0.835739
# 11  0.029361 -0.378455  0.613108
# 12 -1.512480  1.022456 -0.348305
# 13  0.484774 -0.604588 -0.282236
# 14 -0.024333 -0.272521 -0.620488
# 15 -1.944041 -0.772067  0.316481
# 16  2.501638  0.270348  0.195354
# 17  0.112860  1.713175 -0.123474
# 18 -0.014433 -1.051460 -0.242817
# 19 -1.866172  2.277160 -0.435892
# 20 -1.280470 -0.906373 -0.842287
# 21 -2.361269 -0.196354 -1.235610
# 22  0.326205 -1.635643 -0.206706
# 23  1.265236  3.020689  0.349580
# 24  0.005822 -1.919100 -1.166829
# 25  0.308873  0.187074  0.423243
# 26 -0.909836  0.307032 -0.954696
# 27 -0.285961  0.627905  1.571183
# 28 -1.102363 -0.979453 -1.271621
# 29 -0.379782  0.213204  0.878582
# 30  1.621606  1.087445 -1.844480
# 31  1.403256  0.679974 -1.655083
# 32 -0.470766  0.267046  0.049379
# 33 -0.210087  0.304957  0.750896
# 34  0.382165 -0.374029 -0.173351
# 35  0.672521  0.442046  0.093250
# 36  0.178457 -2.337900 -1.509965
# 37  0.112995 -0.267883 -0.529300
# 38 -0.061784  0.542731 -0.224754
# 39  0.579721 -1.516092 -0.258428
# 40 -0.664565  0.821843 -0.418738
# 41 -0.096246 -0.431174 -0.565806
# 42  0.354687  0.134107 -0.978821
# 43  0.526044  1.258962  0.593834
# 44 -0.593388  0.396543  0.222624
# 45 -1.123454 -0.751372 -0.262738
# 46 -0.137665 -0.375808  0.325818
# 47  0.181701 -1.373649 -0.340255
# 48  0.529484 -0.162104 -0.920387
# 49 -1.184310 -1.568484 -0.882209

# %% [markdown]
# We can statistically summarize it like this:

# %%
data.describe()
# Out:
#                A          B          C          D          E          F  \
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean   -0.222337   0.035980   0.274168   0.063683  -0.175400  -0.083430
# std     0.853798   0.940347   0.967988   1.117656   1.022266   1.053182
# min    -1.968782  -2.468129  -1.891905  -2.261109  -2.409686  -2.856200
# 25%    -0.817566  -0.652291  -0.344017  -0.601825  -0.792258  -0.608003
# 50%    -0.227218   0.005299   0.148726  -0.083965  -0.366955  -0.212117
# 75%     0.343336   0.826569   0.966908   0.822371   0.651383   0.536963
# max     1.597170   1.686520   2.364942   2.768409   2.125620   2.249411
#
#                G          H          I          J
# count  50.000000  50.000000  50.000000  50.000000
# mean   -0.170926  -0.093148  -0.018117  -0.192426
# std     0.808752   0.945284   1.085262   0.800840
# min    -1.897425  -2.361269  -2.337900  -1.844480
# 25%    -0.665107  -0.646771  -0.716275  -0.866149
# 50%    -0.208209  -0.004306   0.117767  -0.233785
# 75%     0.337070   0.500924   0.571871   0.343640
# max     1.599085   2.501638   3.020689   1.571183

# %% [markdown]
# We can also get the means of each column:

# %%
data.mean()
# Out:
# A   -0.222337
# B    0.035980
# C    0.274168
# D    0.063683
# E   -0.175400
# F   -0.083430
# G   -0.170926
# H   -0.093148
# I   -0.018117
# J   -0.192426
# dtype: float64

# %% [markdown]
# the variances of each column:

# %%
data.var()
# Out:
# A    0.728971
# B    0.884252
# C    0.937001
# D    1.249154
# E    1.045029
# F    1.109192
# G    0.654079
# H    0.893562
# I    1.177793
# J    0.641345
# dtype: float64

# %% [markdown]
# and the standard deviations of each column:

# %%
data.std()
# Out:
# A    0.853798
# B    0.940347
# C    0.967988
# D    1.117656
# E    1.022266
# F    1.053182
# G    0.808752
# H    0.945284
# I    1.085262
# J    0.800840
# dtype: float64

# %% [markdown]
# ## Transposing DataFrames
# We can transpose a DataFrame by reversing its columns and indexes.

# %%
data.transpose()
# Out:
#          0         1         2         3         4         5         6   \
# A -0.259190 -0.976455 -0.119066 -0.904966 -0.528633 -0.817783 -0.147122
# B  0.170754 -0.472629  1.017724  0.121057 -0.560854 -0.896830  1.077447
# C -1.124605  1.482042  0.387901 -0.590445 -0.930889  0.108925 -0.102460
# D -0.771915  1.802155  1.951747  0.960849  0.115935 -0.315767 -0.107177
# E  0.973286  0.662279 -0.452727  0.284733 -0.825676  1.115497  0.314880
# F -0.946376  0.645750 -0.433070  0.513823 -0.576343  0.424926  1.698336
# G  0.305876 -0.178106 -1.549471 -0.476244 -1.582058 -0.238312  0.776135
# H  0.583443  0.756834 -0.362654  0.506307  1.027357  0.834312 -1.096879
# I -0.610982 -0.975938  0.803287  1.818822  0.241012  1.036758  0.101428
# J -1.349279  1.291805  0.037094  0.741055  0.295293  0.570735 -1.019163
#
#          7         8         9   ...        40        41        42        43  \
# A -0.669262 -0.834004 -0.684567  ...  0.363725  0.077772  0.014714 -0.245146
# B  0.434427  0.883366  0.802311  ... -2.468129  0.780231 -0.046698  1.686520
# C -0.017197 -1.273101  0.930923  ... -0.031613 -0.275987 -0.251996  1.474020
# D -0.683233 -0.254702 -0.165524  ...  0.290612  2.768409 -0.082417  0.832428
# E -0.537647  1.240292  1.046815  ...  0.083103 -0.297156 -0.154091 -1.204790
# F  0.520835  1.192153 -0.266683  ...  2.249411 -0.964066 -0.546341  1.133447
#
#          44        45        46        47        48        49
# A -0.184587  0.282169  0.707604 -0.027832 -1.360113 -1.618905
# B  1.312425  0.343365 -0.970614 -0.173137 -0.838715 -0.610666
# C  1.441163  1.578689  0.042302  0.512214  2.364942  0.103890
# D  0.013772 -0.600533 -1.823481  1.564469  1.478743  0.011803
# E  0.781572 -0.522298  1.655602 -1.328802 -0.829626 -1.928664
# F -1.326372  0.554261 -2.260195 -1.156235 -0.048703  1.043995
# G -1.897425 -0.726182  0.815639  0.368367  0.532980 -1.207603
# H -0.593388 -1.123454 -0.137665  0.181701  0.529484 -1.184310
# I  0.396543 -0.751372 -0.375808 -1.373649 -0.162104 -1.568484
# J  0.222624 -0.262738  0.325818 -0.340255 -0.920387 -0.882209
#
# [10 rows x 50 columns]

# %% [markdown]
# ### Sorting a DataFrame
#
# We can sort indexes, column names, or the values of a DataFrame. For example, the following sorts the indexes (`axis=0`) of the DataFrame in an ascending order:

# %%
mt.sort_index(axis=0)
# Out:
#      byOne  byTwo  byThree  byFour  byFive
# x1       1      2        3       4       5
# x10     10     20       30      40      50
# x2       2      4        6       8      10
# x3       3      6        9      12      15
# x4       4      8       12      16      20
# x5       5     10       15      20      25
# x6       6     12       18      24      30
# x7       7     14       21      28      35
# x8       8     16       24      32      40
# x9       9     18       27      36      45

# %% [markdown]
# The following sorts the columns (`axis=1`) of the DataFrame in a descending order:

# %%
mt.sort_index(axis=1, ascending=False)
# Out:
#      byTwo  byThree  byOne  byFour  byFive
# x1       2        3      1       4       5
# x2       4        6      2       8      10
# x3       6        9      3      12      15
# x4       8       12      4      16      20
# x5      10       15      5      20      25
# x6      12       18      6      24      30
# x7      14       21      7      28      35
# x8      16       24      8      32      40
# x9      18       27      9      36      45
# x10     20       30     10      40      50

# %% [markdown]
# Here is how to sort the values a given a column

# %%
mt.sort_values('byThree', ascending=False)
# Out:
#      byOne  byTwo  byThree  byFour  byFive
# x10     10     20       30      40      50
# x9       9     18       27      36      45
# x8       8     16       24      32      40
# x7       7     14       21      28      35
# x6       6     12       18      24      30
# x5       5     10       15      20      25
# x4       4      8       12      16      20
# x3       3      6        9      12      15
# x2       2      4        6       8      10
# x1       1      2        3       4       5

# %% [markdown]
# and here is how to sort a value of a given row

# %%
mt.sort_values('x5', ascending=False, axis=1)
# Out:
#      byFive  byFour  byThree  byTwo  byOne
# x1        5       4        3      2      1
# x2       10       8        6      4      2
# x3       15      12        9      6      3
# x4       20      16       12      8      4
# x5       25      20       15     10      5
# x6       30      24       18     12      6
# x7       35      28       21     14      7
# x8       40      32       24     16      8
# x9       45      36       27     18      9
# x10      50      40       30     20     10

# %% [markdown]
# ## CHALLENGE 01
# Recreate the 12 times table (see https://www.mathsisfun.com/tables.html) one column at a time. Start by creating an empty DataFrame representing the table. Use a Series object to create the first column and add it to the table. Move on the next column and do the same. And so on for the remaining columns. Use may use loops and expressions to calculate the values of these columns and avoid hard-coding values and code repetition.

# %%
# TODO
